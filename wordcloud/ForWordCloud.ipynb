# %%
import pandas as pd
import csv
import json

# %%
df_k = pd.read_csv('./type/5.csv')
df_k
# Out:
#     seq  count
# 0    好吃  87341
# 1    餐點  44365
# 2    蛋餅  28002
# 3    不錯  24417
# 4    服務  24335
# 5    環境  21422
# 6    親切  19266
# 7    價格  17557
# 8    早餐  17113
# 9   早餐店  13753
# 10  很好吃  13528
# 11   美味  13402
# 12   態度  13125
# 13   份量  12049
# 14   吐司  11269
# 15   用餐  10557
# 16   便宜  10313
# 17   口味  10015
# 18   味道   9939
# 19  早午餐   9852
# 20   很好   9684
# 21   推薦   9016
# 22   豆漿   8699
# 23   舒適   8183
# 24   喜歡   8005
# 25  cp值   7776
# 26   乾淨   7711
# 27  不錯吃   7695
# 28   飲料   7165
# 29   好喝   7094
# 30    蛋   6824
# 31   漢堡   6641
# 32   特別   6594
# 33    讚   6520
# 34   普通   5998
# 35   用心   5827
# 36   新鮮   5796
# 37   值得   5784
# 38   速度   5588
# 39   很棒   5518
# 40  超好吃   5391
# 41   人員   5341
# 42   氣氛   5173
# 43   實在   5066
# 44   紅茶   4939
# 45   時間   4859
# 46   出餐   4803
# 47   套餐   4735

# %%
type(df_k)
# Out:
# pandas.core.frame.DataFrame

# %%
dict_country = df_k.to_dict('record')
data1 = {'city':'早餐', 'word_list' : dict_country}
data1 =[data1]
data1
# Out:
# /Users/yfwang/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py:1485: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(
# [{'city': '早餐',
#   'word_list': [{'seq': '好吃', 'count': 87341},
#    {'seq': '餐點', 'count': 44365},
#    {'seq': '蛋餅', 'count': 28002},
#    {'seq': '不錯', 'count': 24417},
#    {'seq': '服務', 'count': 24335},
#    {'seq': '環境', 'count': 21422},
#    {'seq': '親切', 'count': 19266},
#    {'seq': '價格', 'count': 17557},
#    {'seq': '早餐', 'count': 17113},
#    {'seq': '早餐店', 'count': 13753},
#    {'seq': '很好吃', 'count': 13528},
#    {'seq': '美味', 'count': 13402},
#    {'seq': '態度', 'count': 13125},
#    {'seq': '份量', 'count': 12049},
#    {'seq': '吐司', 'count': 11269},
#    {'seq': '用餐', 'count': 10557},
#    {'seq': '便宜', 'count': 10313},
#    {'seq': '口味', 'count': 10015},
# ...

# %%
with open('test_word.json', 'w', encoding="utf-8") as f:
    json.dump(group, f, ensure_ascii=False, indent=4)

# %%
with open('./type/json/5.json', 'w', encoding="utf-8") as f:
    json.dump(data1, f, ensure_ascii=False, indent=4)

# %%
with open ('test_word.json', 'w', encoding='utf-8') as file:
    df1.to_json(file, indent=4, orient='records', force_asci=False)#
